# %% [markdown]
# <a href="https://colab.research.google.com/github/husnah-rplgank/Phyton-gng/blob/main/Materi_pertama_phyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# materi pertama pembelajaran tentang phyton

# %%
a=3
b=2
c=a+b
print (c)
# Out:
# 5
